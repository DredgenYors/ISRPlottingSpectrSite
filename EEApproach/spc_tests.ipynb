# %%
import sys
#sys.path.append('/Users/marco/Development/Python/ISR/isr_spectrum/src/')
sys.path.append('../src/')
print(sys.path)
# Out:
# ['c:\\Users\\Brandon\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip', 'c:\\Users\\Brandon\\AppData\\Local\\Programs\\Python\\Python310\\DLLs', 'c:\\Users\\Brandon\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'c:\\Users\\Brandon\\AppData\\Local\\Programs\\Python\\Python310', '', 'C:\\Users\\Brandon\\AppData\\Roaming\\Python\\Python310\\site-packages', 'C:\\Users\\Brandon\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32', 'C:\\Users\\Brandon\\AppData\\Roaming\\Python\\Python310\\site-packages\\win32\\lib', 'C:\\Users\\Brandon\\AppData\\Roaming\\Python\\Python310\\site-packages\\Pythonwin', 'c:\\Users\\Brandon\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages', '../src/']

# %%
import plasma_parameters as plasma_param
import physical_constants as phys_cons
from isr_spectrum import isrSpectrum
import numpy as np
import matplotlib.pyplot as plt
import time 
# %matplotlib ipympl

# %%
Ne = 2E11
Bm = 36E-6
Te = 500
Ti = 500
ion_mass = 16
ion_comp = 1
#Ti = 1000.
#ion_mass = 16
#ion_comp = 1

plasma = plasma_param.Plasma(Ne,Bm,Te,Ti,ion_mass,ion_comp)

N = int(100E3)
fs = 12E6
frad = 440E6
lambdaB = phys_cons.c / frad / 2
aspdeg = 30
modgy = 1
modnu = 2

isr_spc = isrSpectrum(N,fs,lambdaB,aspdeg,plasma,modgy=modgy,modnu=modnu)

# %%
plt.figure()
plt.plot(isr_spc.f/1E3,10*np.log10(isr_spc.spc))
#plt.plot(isr_spc.f/1E3,10*np.log10(isr_spc.spc))
#plt.plot(isr_spc.f/1E3,10*np.log10(isr_spc.spce))
#plt.plot(isr_spc.f/1E3,10*np.log10(isr_spc.spci))
plt.grid()
plt.xlim([-fs/2E3,fs/2E3])
plt.xlabel('Frequency [kHz]')
plt.title('Eficiency factor %0.8f' % isr_spc.nrcs)
# Out:
# Text(0.5, 1.0, 'Eficiency factor 0.50101038')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#modgy = 1
#modnu = 2
    
plasma = plasma_param.Plasma(Ne,Bm,Te,Ti,ion_mass,ion_comp)

isr_spc = isrSpectrum(N,fs,lambdaB,aspdeg,plasma,modgy=modgy,modnu=modnu)

# %%
spc_dB = 10*np.log10(isr_spc.spc)

plt.figure()
plt.plot(isr_spc.f/1E3,spc_dB)
plt.grid()
plt.xlim([-fs/2E3,fs/2E3])
plt.xlabel('Frequency [kHz]')

#plt.figure()
#im = plt.pcolormesh(f/1E3,np.arange(M),spc_dB.T,shading='auto',cmap='jet')
#plt.colorbar(im)
#plt.xlabel('Frequency [kHz]')
# Out:
# Text(0.5, 0, 'Frequency [kHz]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
